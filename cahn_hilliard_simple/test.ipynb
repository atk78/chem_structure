# %%
from src.cahn_hilliard import CahnHilliard


CH = CahnHilliard(
    c0=0.5,
    M=1.0,
    kappa=1.0,
    W=2.0,
    Nxy=32,
    Nz=32,
    n_steps=10000,
    save_per_steps=1000
)
CH.compute_c()
# Out:
# 100%|██████████| 10/10 [00:23<00:00,  2.39s/it]

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.load(r"D:\programming\python\2_advance\chem_structure\cahn_hilliard_simple\output\c0_0.5_M_1.0_kappa_1.0_W_2.0_dim_2\npy\2000_step.npy")
plt.imshow(a, cmap='gray')
plt.show()

# %%
a.shape
